# %% [markdown]
# # Autoencoders

# %%
import warnings
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import keras.backend as K
from keras.layers import Input, Dense, Flatten, Reshape, Conv2D, MaxPooling2D, UpSampling2D, Lambda
from keras.models import Model
from keras.regularizers import L1L2
from keras.datasets import mnist

# %% [markdown]
# ### Using GPU, if CUDA lets me...

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  1

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test  = x_test .astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test  = np.reshape(x_test,  (len(x_test),  28, 28, 1))

# %% [markdown]
# ## Simple autoencoder

# %%
def create_dense_ae():
    # Encoded representation dimesion
    encoding_dim = 49

    # Encoder
    # Input placeholder
    input_img = Input(shape=(28, 28, 1)) # 28, 28, 1 - sizes of rows, cols, filters of 1 image
    # Utility reshape layer
    flat_img = Flatten()(input_img)
    # Encode with dense layer -> representation
    encoded = Dense(encoding_dim, activation="relu")(flat_img)
    
    # Decoder
    # Decode with dense layer -> image
    input_encoded = Input(shape=(encoding_dim,))
    flat_decoded = Dense(28*28, activation="sigmoid")(input_encoded)
    decoded = Reshape((28, 28, 1))(flat_decoded)

    #                 input     other
    encoder = Model(input_img, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
    return encoder, decoder, autoencoder

encoder, decoder, autoencoder = create_dense_ae()
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")

autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  encoder (Functional)        (None, 49)                38465
#
#  decoder (Functional)        (None, 28, 28, 1)         39200
#
# =================================================================
# Total params: 77,665
# Trainable params: 77,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0790 - val_loss: 0.0781
# Epoch 2/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0789 - val_loss: 0.0781
# Epoch 3/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0789 - val_loss: 0.0781
# Epoch 4/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0788 - val_loss: 0.0780
# Epoch 5/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0788 - val_loss: 0.0781
# Epoch 6/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0788 - val_loss: 0.0779
# Epoch 7/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0787 - val_loss: 0.0780
# Epoch 8/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0787 - val_loss: 0.0780
# Epoch 9/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0787 - val_loss: 0.0779
# Epoch 10/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0787 - val_loss: 0.0779
# Epoch 11/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0786 - val_loss: 0.0778
# Epoch 12/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0786 - val_loss: 0.0778
# Epoch 13/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0786 - val_loss: 0.0779
# Epoch 14/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0786 - val_loss: 0.0779
# Epoch 15/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0786 - val_loss: 0.0778
# Epoch 16/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0785 - val_loss: 0.0779
# Epoch 17/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0785 - val_loss: 0.0779
# Epoch 18/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0785 - val_loss: 0.0778
# Epoch 19/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0785 - val_loss: 0.0778
# Epoch 20/50
#  48/235 [=====>........................] - ETA: 0s - loss: 0.0787
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 tf.debugging.set_log_device_placement(True)
# ----> 3 autoencoder.fit(x_train, x_train,
#       4                 epochs=50,
#       5                 batch_size=256,
#       6                 shuffle=True,
#       7                 validation_data=(x_test, x_test))
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/context.py:942, in Context._handle(self)
#     938   self.ensure_initialized()
#     939   pywrap_tfe.TFE_CollectiveOpsCheckPeerHealth(self._handle, task,
#     940                                               timeout_in_ms)
# --> 942 @property
#     943 def _handle(self):
#     944   if self._context_handle is None:
#     945     raise AssertionError("Context must be initialized first.")
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plotter function

# %%
def plot_digits(*args):
    args = [x.squeeze() for x in args]
    n = min([x.shape[0] for x in args])
    
    plt.figure(figsize=(2*n, 2*len(args)))
    for j in range(n):
        for i in range(len(args)):
            ax = plt.subplot(len(args), n, i*n + j + 1)
            plt.imshow(args[i][j])
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)

    plt.show()

# %%
n = 10

imgs = x_test[:n]
encoded_imgs = encoder.predict(imgs, batch_size=n)

decoded_imgs = decoder.predict(encoded_imgs, batch_size=n)

plot_digits(imgs, decoded_imgs)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step

# %% [markdown]
# ## Deep AE

# %%
def create_deep_dense_ae():
    # Encoded representation dimension
    encoding_dim = 49

    # Encoder
    input_img = Input(shape=(28, 28, 1))
    flat_img = Flatten()(input_img)
    x = Dense(encoding_dim*3, activation="relu")(flat_img)
    x = Dense(encoding_dim*2, activation="relu")(x)
    encoded = Dense(encoding_dim, activation='linear')(x)
    
    # Decoder
    input_encoded = Input(shape=(encoding_dim,))
    x = Dense(encoding_dim*2, activation="relu")(input_encoded)
    x = Dense(encoding_dim*3, activation="relu")(x)
    flat_decoded = Dense(28*28, activation="sigmoid")(x)
    decoded = Reshape((28, 28, 1))(flat_decoded)
    
    # Models
    encoder = Model(input_img, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
    return encoder, decoder, autoencoder

d_encoder, d_decoder, d_autoencoder = create_deep_dense_ae()
d_autoencoder.compile(optimizer="adam", loss="binary_crossentropy")

d_autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  encoder (Functional)        (None, 49)                134750
#
#  decoder (Functional)        (None, 28, 28, 1)         135485
#
# =================================================================
# Total params: 270,235
# Trainable params: 270,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
d_autoencoder.fit(x_train, x_train,
                  epochs=100,
                  batch_size=256,
                  shuffle=True,
                  validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 2022-09-18 22:51:24.176011: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# 235/235 [==============================] - 3s 10ms/step - loss: 0.2226 - val_loss: 0.1473
# Epoch 2/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1342 - val_loss: 0.1231
# Epoch 3/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1178 - val_loss: 0.1106
# Epoch 4/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1084 - val_loss: 0.1033
# Epoch 5/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1025 - val_loss: 0.0991
# Epoch 6/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0987 - val_loss: 0.0960
# Epoch 7/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0960 - val_loss: 0.0939
# Epoch 8/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0937 - val_loss: 0.0914
# Epoch 9/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0918 - val_loss: 0.0901
# Epoch 10/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0903 - val_loss: 0.0888
# Epoch 11/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0892 - val_loss: 0.0879
# Epoch 12/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0881 - val_loss: 0.0873
# Epoch 13/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0871 - val_loss: 0.0861
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0863 - val_loss: 0.0856
# Epoch 15/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0855 - val_loss: 0.0842
# Epoch 16/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0848 - val_loss: 0.0836
# Epoch 17/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0841 - val_loss: 0.0832
# Epoch 18/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0835 - val_loss: 0.0833
# Epoch 19/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0830 - val_loss: 0.0822
# Epoch 20/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0825 - val_loss: 0.0816
# Epoch 21/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0820 - val_loss: 0.0813
# Epoch 22/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0816 - val_loss: 0.0807
# Epoch 23/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0811 - val_loss: 0.0810
# Epoch 24/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0808 - val_loss: 0.0801
# Epoch 25/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0804 - val_loss: 0.0798
# Epoch 26/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0801 - val_loss: 0.0793
# Epoch 27/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0798 - val_loss: 0.0796
# Epoch 28/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0796 - val_loss: 0.0793
# Epoch 29/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0793 - val_loss: 0.0793
# Epoch 30/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0791 - val_loss: 0.0785
# Epoch 31/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0789 - val_loss: 0.0785
# Epoch 32/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0786 - val_loss: 0.0783
# Epoch 33/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0784 - val_loss: 0.0781
# Epoch 34/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0782 - val_loss: 0.0779
# Epoch 35/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0780 - val_loss: 0.0777
# Epoch 36/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0778 - val_loss: 0.0774
# Epoch 37/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0777 - val_loss: 0.0774
# Epoch 38/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0775 - val_loss: 0.0771
# Epoch 39/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0774 - val_loss: 0.0768
# Epoch 40/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0771 - val_loss: 0.0768
# Epoch 41/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0770 - val_loss: 0.0769
# Epoch 42/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0768 - val_loss: 0.0762
# Epoch 43/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0767 - val_loss: 0.0764
# Epoch 44/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0766 - val_loss: 0.0765
# Epoch 45/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0764 - val_loss: 0.0762
# Epoch 46/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0763 - val_loss: 0.0760
# Epoch 47/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0762 - val_loss: 0.0758
# Epoch 48/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0760 - val_loss: 0.0760
# Epoch 49/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0759 - val_loss: 0.0758
# Epoch 50/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0757 - val_loss: 0.0755
# Epoch 51/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0757 - val_loss: 0.0752
# Epoch 52/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0756 - val_loss: 0.0752
# Epoch 53/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0754 - val_loss: 0.0753
# Epoch 54/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0754 - val_loss: 0.0751
# Epoch 55/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0753 - val_loss: 0.0749
# Epoch 56/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0752 - val_loss: 0.0750
# Epoch 57/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0751 - val_loss: 0.0748
# Epoch 58/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0750 - val_loss: 0.0747
# Epoch 59/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0749 - val_loss: 0.0747
# Epoch 60/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0749 - val_loss: 0.0747
# Epoch 61/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0747 - val_loss: 0.0746
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0747 - val_loss: 0.0747
# Epoch 63/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0746 - val_loss: 0.0744
# Epoch 64/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0745 - val_loss: 0.0743
# Epoch 65/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0744 - val_loss: 0.0745
# Epoch 66/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0744 - val_loss: 0.0743
# Epoch 67/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0743 - val_loss: 0.0741
# Epoch 68/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0742 - val_loss: 0.0742
# Epoch 69/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0742 - val_loss: 0.0740
# Epoch 70/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0741 - val_loss: 0.0738
# Epoch 71/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0740 - val_loss: 0.0739
# Epoch 72/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0740 - val_loss: 0.0737
# Epoch 73/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0739 - val_loss: 0.0738
# Epoch 74/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0739 - val_loss: 0.0740
# Epoch 75/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0738 - val_loss: 0.0737
# Epoch 76/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0737 - val_loss: 0.0737
# Epoch 77/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0737 - val_loss: 0.0734
# Epoch 78/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0736 - val_loss: 0.0737
# Epoch 79/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0735 - val_loss: 0.0733
# Epoch 80/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0735 - val_loss: 0.0735
# Epoch 81/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0735 - val_loss: 0.0736
# Epoch 82/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0734 - val_loss: 0.0733
# Epoch 83/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0733 - val_loss: 0.0731
# Epoch 84/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0733 - val_loss: 0.0733
# Epoch 85/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0732 - val_loss: 0.0731
# Epoch 86/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0732 - val_loss: 0.0730
# Epoch 87/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0731 - val_loss: 0.0730
# Epoch 88/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0731 - val_loss: 0.0731
# Epoch 89/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0730 - val_loss: 0.0729
# Epoch 90/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0729 - val_loss: 0.0730
# Epoch 91/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0730 - val_loss: 0.0729
# Epoch 92/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0729 - val_loss: 0.0729
# Epoch 93/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0729 - val_loss: 0.0730
# Epoch 94/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0728 - val_loss: 0.0727
# Epoch 95/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0728 - val_loss: 0.0726
# Epoch 96/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0727 - val_loss: 0.0727
# Epoch 97/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0727 - val_loss: 0.0726
# Epoch 98/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0727 - val_loss: 0.0726
# Epoch 99/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0726 - val_loss: 0.0726
# Epoch 100/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0726 - val_loss: 0.0725

# %%
n = 10

imgs = x_test[:n]
encoded_imgs = d_encoder.predict(imgs, batch_size=n)

decoded_imgs = d_decoder.predict(encoded_imgs, batch_size=n)

plot_digits(imgs, decoded_imgs)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step

# %% [markdown]
# ## Deep convolutional AE

# %%
def create_deep_conv_ae():
    input_img = Input(shape=(28, 28, 1))

    x = Conv2D(128, (7, 7), activation="relu", padding="same")(input_img)
    x = MaxPooling2D((2, 2), padding="same")(x)
    x = Conv2D(32, (2, 2), activation="relu", padding="same")(x)
    x = MaxPooling2D((2, 2), padding="same")(x)
    encoded = Conv2D(1, (7, 7), activation="relu", padding="same")(x)

    # Here the representation is (7, 7, 1), dim=49

    input_encoded = Input(shape=(7, 7, 1))
    x = Conv2D(32, (7, 7), activation="relu", padding="same")(input_encoded)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(128, (2, 2), activation="relu", padding="same")(x)
    x = UpSampling2D((2, 2))(x)
    decoded = Conv2D(1, (7, 7), activation="sigmoid", padding="same")(x)

    # Models
    encoder = Model(input_img, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
    return encoder, decoder, autoencoder

c_encoder, c_decoder, c_autoencoder = create_deep_conv_ae()
c_autoencoder.compile(optimizer="adam", loss="binary_crossentropy")

c_autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  encoder (Functional)        (None, 7, 7, 1)           24385
#
#  decoder (Functional)        (None, 28, 28, 1)         24385
#
# =================================================================
# Total params: 48,770
# Trainable params: 48,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
c_autoencoder.fit(x_train, x_train,
                epochs=64,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))

# %%
n = 10

imgs = x_test[:n]
encoded_imgs = c_encoder.predict(imgs, batch_size=n)
decoded_imgs = c_decoder.predict(encoded_imgs, batch_size=n)

plot_digits(imgs, decoded_imgs)

# %% [markdown]
# ## Denoising AE

# %%
batch_size = 16

def create_denoising_model(autoencoder):
    def add_noise(x):
        noise_factor = 0.5
        x = x + K.random_normal(x.get_shape(), 0.5, noise_factor)
        x = K.clip(x, 0., 1.)
        return x

    input_img  = Input(batch_shape=(batch_size, 28, 28, 1))
    noised_img = Lambda(add_noise)(input_img)

    noiser = Model(input_img, noised_img, name="noiser")
    denoiser_model = Model(input_img, autoencoder(noiser(input_img)), name="denoiser")
    return noiser, denoiser_model


noiser, denoiser_model = create_denoising_model(autoencoder)
denoiser_model.compile(optimizer="adam", loss="binary_crossentropy")

denoiser_model.summary()
# Out:
# Model: "denoiser"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(16, 28, 28, 1)]         0
#
#  noiser (Functional)         (16, 28, 28, 1)           0
#
#  autoencoder (Functional)    (None, 28, 28, 1)         77665
#
# =================================================================
# Total params: 77,665
# Trainable params: 77,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
denoiser_model.fit(x_train, x_train,
                   epochs=200,
                   batch_size=batch_size,
                   shuffle=True,
                   validation_data=(x_test, x_test))
# Out:
# Epoch 1/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1688 - val_loss: 0.1376
# Epoch 2/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1361 - val_loss: 0.1343
# Epoch 3/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1326 - val_loss: 0.1306
# Epoch 4/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1313 - val_loss: 0.1287
# Epoch 5/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1304 - val_loss: 0.1279
# Epoch 6/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1298 - val_loss: 0.1279
# Epoch 7/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1294 - val_loss: 0.1276
# Epoch 8/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1292 - val_loss: 0.1264
# Epoch 9/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1288 - val_loss: 0.1274
# Epoch 10/200
# 3750/3750 [==============================] - 6s 1ms/step - loss: 0.1286 - val_loss: 0.1269
# Epoch 11/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1285 - val_loss: 0.1280
# Epoch 12/200
# 3750/3750 [==============================] - 6s 1ms/step - loss: 0.1283 - val_loss: 0.1275
# Epoch 13/200
# 3750/3750 [==============================] - 6s 1ms/step - loss: 0.1282 - val_loss: 0.1268
# Epoch 14/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1280 - val_loss: 0.1262
# Epoch 15/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1280 - val_loss: 0.1267
# Epoch 16/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1278 - val_loss: 0.1260
# Epoch 17/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1278 - val_loss: 0.1262
# Epoch 18/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1277 - val_loss: 0.1272
# Epoch 19/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1277 - val_loss: 0.1266
# Epoch 20/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1277 - val_loss: 0.1263
# Epoch 21/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1275 - val_loss: 0.1266
# Epoch 22/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1274 - val_loss: 0.1269
# Epoch 23/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1272 - val_loss: 0.1254
# Epoch 24/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1273 - val_loss: 0.1255
# Epoch 25/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1272 - val_loss: 0.1250
# Epoch 26/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1272 - val_loss: 0.1255
# Epoch 27/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1271 - val_loss: 0.1276
# Epoch 28/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1271 - val_loss: 0.1250
# Epoch 29/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1270 - val_loss: 0.1273
# Epoch 30/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1269 - val_loss: 0.1251
# Epoch 31/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1270 - val_loss: 0.1259
# Epoch 32/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1269 - val_loss: 0.1255
# Epoch 33/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1268 - val_loss: 0.1250
# Epoch 34/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1267 - val_loss: 0.1254
# Epoch 35/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1266 - val_loss: 0.1248
# Epoch 36/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1266 - val_loss: 0.1246
# Epoch 37/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1266 - val_loss: 0.1240
# Epoch 38/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1265 - val_loss: 0.1240
# Epoch 39/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1265 - val_loss: 0.1249
# Epoch 40/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1263 - val_loss: 0.1243
# Epoch 41/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1264 - val_loss: 0.1248
# Epoch 42/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1262 - val_loss: 0.1264
# Epoch 43/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1263 - val_loss: 0.1247
# Epoch 44/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1261 - val_loss: 0.1250
# Epoch 45/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1262 - val_loss: 0.1243
# Epoch 46/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1261 - val_loss: 0.1253
# Epoch 47/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1262 - val_loss: 0.1245
# Epoch 48/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1262 - val_loss: 0.1242
# Epoch 49/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1260 - val_loss: 0.1240
# Epoch 50/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1259 - val_loss: 0.1255
# Epoch 51/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1260 - val_loss: 0.1240
# Epoch 52/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1260 - val_loss: 0.1237
# Epoch 53/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1258 - val_loss: 0.1240
# Epoch 54/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1259 - val_loss: 0.1243
# Epoch 55/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1258 - val_loss: 0.1241
# Epoch 56/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1257 - val_loss: 0.1240
# Epoch 57/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1257 - val_loss: 0.1253
# Epoch 58/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1256 - val_loss: 0.1242
# Epoch 59/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1256 - val_loss: 0.1246
# Epoch 60/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1256 - val_loss: 0.1260
# Epoch 61/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1257 - val_loss: 0.1244
# Epoch 62/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1256 - val_loss: 0.1230
# Epoch 63/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1256 - val_loss: 0.1237
# Epoch 64/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1256 - val_loss: 0.1243
# Epoch 65/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1255 - val_loss: 0.1234
# Epoch 66/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1253 - val_loss: 0.1234
# Epoch 67/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1254 - val_loss: 0.1237
# Epoch 68/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1254 - val_loss: 0.1237
# Epoch 69/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1253 - val_loss: 0.1235
# Epoch 70/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1252 - val_loss: 0.1232
# Epoch 71/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1251 - val_loss: 0.1241
# Epoch 72/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1252 - val_loss: 0.1237
# Epoch 73/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1252 - val_loss: 0.1235
# Epoch 74/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1252 - val_loss: 0.1232
# Epoch 75/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1252 - val_loss: 0.1231
# Epoch 76/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1251 - val_loss: 0.1237
# Epoch 77/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1250 - val_loss: 0.1239
# Epoch 78/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1250 - val_loss: 0.1233
# Epoch 79/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1249 - val_loss: 0.1237
# Epoch 80/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1250 - val_loss: 0.1232
# Epoch 81/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1249 - val_loss: 0.1229
# Epoch 82/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1250 - val_loss: 0.1234
# Epoch 83/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1250 - val_loss: 0.1230
# Epoch 84/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1250 - val_loss: 0.1231
# Epoch 85/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1249 - val_loss: 0.1230
# Epoch 86/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1248 - val_loss: 0.1236
# Epoch 87/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1248 - val_loss: 0.1234
# Epoch 88/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1249 - val_loss: 0.1233
# Epoch 89/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1249 - val_loss: 0.1226
# Epoch 90/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 91/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1224
# Epoch 92/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1248 - val_loss: 0.1232
# Epoch 93/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1236
# Epoch 94/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1226
# Epoch 95/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1231
# Epoch 96/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1238
# Epoch 97/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1232
# Epoch 98/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1232
# Epoch 99/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1227
# Epoch 100/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1232
# Epoch 101/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1237
# Epoch 102/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1247 - val_loss: 0.1234
# Epoch 103/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1229
# Epoch 104/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1229
# Epoch 105/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1228
# Epoch 106/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1245 - val_loss: 0.1229
# Epoch 107/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1245 - val_loss: 0.1229
# Epoch 108/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1246 - val_loss: 0.1227
# Epoch 109/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1250
# Epoch 110/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1240
# Epoch 111/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1245 - val_loss: 0.1230
# Epoch 112/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1245 - val_loss: 0.1227
# Epoch 113/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1245 - val_loss: 0.1225
# Epoch 114/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1223
# Epoch 115/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1249
# Epoch 116/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1223
# Epoch 117/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1225
# Epoch 118/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1227
# Epoch 119/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1224
# Epoch 120/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1225
# Epoch 121/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1245 - val_loss: 0.1231
# Epoch 122/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1224
# Epoch 123/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1230
# Epoch 124/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1231
# Epoch 125/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1244 - val_loss: 0.1232
# Epoch 126/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1225
# Epoch 127/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1227
# Epoch 128/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1232
# Epoch 129/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1231
# Epoch 130/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1230
# Epoch 131/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1228
# Epoch 132/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1224
# Epoch 133/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1229
# Epoch 134/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1236
# Epoch 135/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1227
# Epoch 136/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1223
# Epoch 137/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1227
# Epoch 138/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1243 - val_loss: 0.1228
# Epoch 139/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1223
# Epoch 140/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1227
# Epoch 141/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1231
# Epoch 142/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1222
# Epoch 143/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1229
# Epoch 144/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1221
# Epoch 145/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1222
# Epoch 146/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1229
# Epoch 147/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1229
# Epoch 148/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1226
# Epoch 149/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1238
# Epoch 150/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1220
# Epoch 151/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1228
# Epoch 152/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1226
# Epoch 153/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1230
# Epoch 154/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1223
# Epoch 155/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1242 - val_loss: 0.1224
# Epoch 156/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1221
# Epoch 157/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1228
# Epoch 158/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1224
# Epoch 159/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1225
# Epoch 160/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1225
# Epoch 161/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1235
# Epoch 162/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1228
# Epoch 163/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1225
# Epoch 164/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1230
# Epoch 165/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1227
# Epoch 166/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1221
# Epoch 167/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1223
# Epoch 168/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1225
# Epoch 169/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1229
# Epoch 170/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1225
# Epoch 171/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1224
# Epoch 172/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1220
# Epoch 173/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1233
# Epoch 174/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1224
# Epoch 175/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1220
# Epoch 176/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1226
# Epoch 177/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1226
# Epoch 178/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1227
# Epoch 179/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1224
# Epoch 180/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1221
# Epoch 181/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1220
# Epoch 182/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1224
# Epoch 183/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1221
# Epoch 184/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1219
# Epoch 185/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1222
# Epoch 186/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1222
# Epoch 187/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1223
# Epoch 188/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1226
# Epoch 189/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1217
# Epoch 190/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1222
# Epoch 191/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1230
# Epoch 192/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1225
# Epoch 193/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1219
# Epoch 194/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1239 - val_loss: 0.1229
# Epoch 195/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1223
# Epoch 196/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1231
# Epoch 197/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1241 - val_loss: 0.1221
# Epoch 198/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1226
# Epoch 199/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1232
# Epoch 200/200
# 3750/3750 [==============================] - 5s 1ms/step - loss: 0.1240 - val_loss: 0.1226

# %%
n = 10

imgs = x_test[:batch_size]
noised_imgs = noiser.predict(imgs, batch_size=batch_size)
encoded_imgs = encoder.predict(noised_imgs[:n],  batch_size=n)
decoded_imgs = decoder.predict(encoded_imgs[:n], batch_size=n)

plot_digits(imgs[:n], noised_imgs, decoded_imgs)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step

# %% [markdown]
# ## Sparse AE

# %%
def create_sparse_ae():
    encoding_dim = 16
    lambda_l1 = 0.00001
    
    # Encoder
    input_img = Input(shape=(28, 28, 1))
    flat_img = Flatten()(input_img)
    x = Dense(encoding_dim*3, activation="relu")(flat_img)
    x = Dense(encoding_dim*2, activation="relu")(x)
    encoded = Dense(encoding_dim, activation="linear", activity_regularizer=L1L2(lambda_l1))(x)
    
    # Decoder
    input_encoded = Input(shape=(encoding_dim,))
    x = Dense(encoding_dim*2, activation="relu")(input_encoded)
    x = Dense(encoding_dim*3, activation="relu")(x)
    flat_decoded = Dense(28*28, activation="sigmoid")(x)
    decoded = Reshape((28, 28, 1))(flat_decoded)
    
    # Models
    encoder = Model(input_img, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
    return encoder, decoder, autoencoder

s_encoder, s_decoder, s_autoencoder = create_sparse_ae()
s_autoencoder.compile(optimizer="adam", loss="binary_crossentropy")

s_autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  encoder (Functional)        (None, 16)                39776
#
#  decoder (Functional)        (None, 28, 28, 1)         40544
#
# =================================================================
# Total params: 80,320
# Trainable params: 80,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
s_autoencoder.fit(x_train, x_train,
                epochs=400,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/400
# 235/235 [==============================] - 1s 5ms/step - loss: 0.2738 - val_loss: 0.1942
# Epoch 2/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1768 - val_loss: 0.1633
# Epoch 3/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1572 - val_loss: 0.1484
# Epoch 4/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1457 - val_loss: 0.1409
# Epoch 5/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1405 - val_loss: 0.1372
# Epoch 6/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1372 - val_loss: 0.1340
# Epoch 7/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1340 - val_loss: 0.1305
# Epoch 8/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1307 - val_loss: 0.1274
# Epoch 9/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1279 - val_loss: 0.1249
# Epoch 10/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1257 - val_loss: 0.1232
# Epoch 11/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1240 - val_loss: 0.1218
# Epoch 12/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1226 - val_loss: 0.1204
# Epoch 13/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1214 - val_loss: 0.1192
# Epoch 14/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1202 - val_loss: 0.1182
# Epoch 15/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1191 - val_loss: 0.1171
# Epoch 16/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1179 - val_loss: 0.1157
# Epoch 17/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1168 - val_loss: 0.1150
# Epoch 18/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1160 - val_loss: 0.1142
# Epoch 19/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1153 - val_loss: 0.1137
# Epoch 20/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1148 - val_loss: 0.1132
# Epoch 21/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1143 - val_loss: 0.1126
# Epoch 22/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1138 - val_loss: 0.1123
# Epoch 23/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1135 - val_loss: 0.1120
# Epoch 24/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1131 - val_loss: 0.1115
# Epoch 25/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1128 - val_loss: 0.1113
# Epoch 26/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1125 - val_loss: 0.1110
# Epoch 27/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1122 - val_loss: 0.1106
# Epoch 28/400
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1119 - val_loss: 0.1106
# Epoch 29/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1117 - val_loss: 0.1104
# Epoch 30/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1114 - val_loss: 0.1101
# Epoch 31/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1112 - val_loss: 0.1098
# Epoch 32/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1110 - val_loss: 0.1097
# Epoch 33/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1108 - val_loss: 0.1095
# Epoch 34/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1106 - val_loss: 0.1093
# Epoch 35/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1104 - val_loss: 0.1091
# Epoch 36/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1102 - val_loss: 0.1089
# Epoch 37/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1100 - val_loss: 0.1089
# Epoch 38/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1099 - val_loss: 0.1089
# Epoch 39/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1097 - val_loss: 0.1086
# Epoch 40/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1095 - val_loss: 0.1082
# Epoch 41/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1094 - val_loss: 0.1083
# Epoch 42/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1092 - val_loss: 0.1081
# Epoch 43/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1091 - val_loss: 0.1078
# Epoch 44/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1090 - val_loss: 0.1078
# Epoch 45/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1088 - val_loss: 0.1077
# Epoch 46/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1087 - val_loss: 0.1075
# Epoch 47/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1086 - val_loss: 0.1075
# Epoch 48/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1084 - val_loss: 0.1074
# Epoch 49/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1083 - val_loss: 0.1073
# Epoch 50/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1082 - val_loss: 0.1072
# Epoch 51/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1081 - val_loss: 0.1071
# Epoch 52/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1079 - val_loss: 0.1070
# Epoch 53/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1079 - val_loss: 0.1069
# Epoch 54/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1077 - val_loss: 0.1066
# Epoch 55/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1076 - val_loss: 0.1066
# Epoch 56/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1075 - val_loss: 0.1065
# Epoch 57/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1075 - val_loss: 0.1064
# Epoch 58/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1073 - val_loss: 0.1062
# Epoch 59/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1072 - val_loss: 0.1062
# Epoch 60/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1072 - val_loss: 0.1063
# Epoch 61/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1071 - val_loss: 0.1060
# Epoch 62/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1070 - val_loss: 0.1059
# Epoch 63/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1069 - val_loss: 0.1058
# Epoch 64/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1068 - val_loss: 0.1056
# Epoch 65/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1067 - val_loss: 0.1058
# Epoch 66/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1067 - val_loss: 0.1056
# Epoch 67/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1066 - val_loss: 0.1057
# Epoch 68/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1065 - val_loss: 0.1055
# Epoch 69/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1064 - val_loss: 0.1055
# Epoch 70/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1063 - val_loss: 0.1053
# Epoch 71/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1063 - val_loss: 0.1055
# Epoch 72/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1062 - val_loss: 0.1052
# Epoch 73/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1061 - val_loss: 0.1052
# Epoch 74/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1061 - val_loss: 0.1051
# Epoch 75/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1060 - val_loss: 0.1053
# Epoch 76/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1060 - val_loss: 0.1051
# Epoch 77/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1059 - val_loss: 0.1051
# Epoch 78/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1058 - val_loss: 0.1049
# Epoch 79/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1058 - val_loss: 0.1047
# Epoch 80/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1057 - val_loss: 0.1048
# Epoch 81/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1057 - val_loss: 0.1046
# Epoch 82/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1056 - val_loss: 0.1047
# Epoch 83/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1055 - val_loss: 0.1046
# Epoch 84/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1055 - val_loss: 0.1049
# Epoch 85/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1055 - val_loss: 0.1044
# Epoch 86/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1054 - val_loss: 0.1047
# Epoch 87/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1054 - val_loss: 0.1045
# Epoch 88/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1053 - val_loss: 0.1047
# Epoch 89/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1053 - val_loss: 0.1045
# Epoch 90/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1052 - val_loss: 0.1046
# Epoch 91/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1052 - val_loss: 0.1043
# Epoch 92/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1051 - val_loss: 0.1044
# Epoch 93/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1051 - val_loss: 0.1043
# Epoch 94/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1051 - val_loss: 0.1042
# Epoch 95/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1051 - val_loss: 0.1041
# Epoch 96/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1050 - val_loss: 0.1041
# Epoch 97/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1050 - val_loss: 0.1041
# Epoch 98/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1049 - val_loss: 0.1040
# Epoch 99/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1049 - val_loss: 0.1041
# Epoch 100/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1049 - val_loss: 0.1040
# Epoch 101/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1049 - val_loss: 0.1039
# Epoch 102/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1048 - val_loss: 0.1040
# Epoch 103/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1047 - val_loss: 0.1039
# Epoch 104/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1048 - val_loss: 0.1040
# Epoch 105/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1047 - val_loss: 0.1039
# Epoch 106/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1047 - val_loss: 0.1039
# Epoch 107/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1046 - val_loss: 0.1037
# Epoch 108/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1046 - val_loss: 0.1038
# Epoch 109/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1046 - val_loss: 0.1039
# Epoch 110/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1046 - val_loss: 0.1036
# Epoch 111/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1045 - val_loss: 0.1038
# Epoch 112/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1045 - val_loss: 0.1036
# Epoch 113/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1045 - val_loss: 0.1038
# Epoch 114/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1045 - val_loss: 0.1038
# Epoch 115/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1044 - val_loss: 0.1036
# Epoch 116/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1044 - val_loss: 0.1035
# Epoch 117/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1044 - val_loss: 0.1037
# Epoch 118/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1043 - val_loss: 0.1035
# Epoch 119/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1043 - val_loss: 0.1034
# Epoch 120/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1043 - val_loss: 0.1033
# Epoch 121/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1043 - val_loss: 0.1034
# Epoch 122/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1043 - val_loss: 0.1034
# Epoch 123/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1042 - val_loss: 0.1035
# Epoch 124/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1042 - val_loss: 0.1034
# Epoch 125/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1042 - val_loss: 0.1033
# Epoch 126/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1042 - val_loss: 0.1036
# Epoch 127/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1041 - val_loss: 0.1033
# Epoch 128/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1040 - val_loss: 0.1032
# Epoch 129/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1040 - val_loss: 0.1031
# Epoch 130/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1040 - val_loss: 0.1032
# Epoch 131/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1040 - val_loss: 0.1030
# Epoch 132/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1039 - val_loss: 0.1032
# Epoch 133/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1039 - val_loss: 0.1031
# Epoch 134/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1039 - val_loss: 0.1031
# Epoch 135/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1038 - val_loss: 0.1031
# Epoch 136/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1038 - val_loss: 0.1031
# Epoch 137/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1038 - val_loss: 0.1029
# Epoch 138/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1037 - val_loss: 0.1030
# Epoch 139/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1037 - val_loss: 0.1029
# Epoch 140/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1037 - val_loss: 0.1029
# Epoch 141/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1037 - val_loss: 0.1030
# Epoch 142/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1036 - val_loss: 0.1029
# Epoch 143/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1036 - val_loss: 0.1030
# Epoch 144/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1036 - val_loss: 0.1028
# Epoch 145/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1036 - val_loss: 0.1028
# Epoch 146/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1035 - val_loss: 0.1028
# Epoch 147/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1035 - val_loss: 0.1027
# Epoch 148/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1035 - val_loss: 0.1025
# Epoch 149/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1034 - val_loss: 0.1027
# Epoch 150/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1034 - val_loss: 0.1027
# Epoch 151/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1034 - val_loss: 0.1028
# Epoch 152/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1034 - val_loss: 0.1026
# Epoch 153/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1034 - val_loss: 0.1027
# Epoch 154/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1033 - val_loss: 0.1026
# Epoch 155/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1033 - val_loss: 0.1025
# Epoch 156/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1033 - val_loss: 0.1025
# Epoch 157/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1033 - val_loss: 0.1025
# Epoch 158/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1033 - val_loss: 0.1024
# Epoch 159/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1032 - val_loss: 0.1024
# Epoch 160/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1032 - val_loss: 0.1027
# Epoch 161/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1032 - val_loss: 0.1024
# Epoch 162/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1032 - val_loss: 0.1023
# Epoch 163/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1032 - val_loss: 0.1023
# Epoch 164/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1025
# Epoch 165/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1024
# Epoch 166/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1024
# Epoch 167/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1023
# Epoch 168/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1023
# Epoch 169/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1023
# Epoch 170/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1030 - val_loss: 0.1023
# Epoch 171/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1031 - val_loss: 0.1023
# Epoch 172/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1030 - val_loss: 0.1021
# Epoch 173/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1030 - val_loss: 0.1022
# Epoch 174/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1030 - val_loss: 0.1022
# Epoch 175/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1022
# Epoch 176/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1022
# Epoch 177/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1021
# Epoch 178/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1021
# Epoch 179/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1021
# Epoch 180/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1021
# Epoch 181/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1029 - val_loss: 0.1023
# Epoch 182/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1020
# Epoch 183/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1020
# Epoch 184/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1020
# Epoch 185/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1021
# Epoch 186/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1020
# Epoch 187/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1021
# Epoch 188/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1028 - val_loss: 0.1021
# Epoch 189/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1019
# Epoch 190/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1020
# Epoch 191/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1019
# Epoch 192/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1020
# Epoch 193/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1020
# Epoch 194/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1021
# Epoch 195/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1020
# Epoch 196/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1021
# Epoch 197/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1027 - val_loss: 0.1019
# Epoch 198/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1019
# Epoch 199/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1019
# Epoch 200/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1019
# Epoch 201/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1020
# Epoch 202/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1018
# Epoch 203/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1019
# Epoch 204/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1020
# Epoch 205/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1018
# Epoch 206/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1026 - val_loss: 0.1018
# Epoch 207/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1019
# Epoch 208/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1017
# Epoch 209/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1020
# Epoch 210/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1019
# Epoch 211/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1019
# Epoch 212/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1018
# Epoch 213/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1017
# Epoch 214/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1017
# Epoch 215/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1016
# Epoch 216/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1025 - val_loss: 0.1020
# Epoch 217/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 218/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 219/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1021
# Epoch 220/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1016
# Epoch 221/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1018
# Epoch 222/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 223/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 224/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 225/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1018
# Epoch 226/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1016
# Epoch 227/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1016
# Epoch 228/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1016
# Epoch 229/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 230/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1015
# Epoch 231/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1019
# Epoch 232/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1018
# Epoch 233/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1016
# Epoch 234/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1016
# Epoch 235/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1016
# Epoch 236/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1016
# Epoch 237/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1015
# Epoch 238/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1015
# Epoch 239/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1017
# Epoch 240/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1023 - val_loss: 0.1018
# Epoch 241/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1015
# Epoch 242/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1017
# Epoch 243/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1016
# Epoch 244/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1015
# Epoch 245/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1016
# Epoch 246/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1016
# Epoch 247/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1016
# Epoch 248/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1016
# Epoch 249/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1015
# Epoch 250/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1022 - val_loss: 0.1015
# Epoch 251/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1015
# Epoch 252/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1015
# Epoch 253/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1015
# Epoch 254/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1015
# Epoch 255/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1016
# Epoch 256/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1016
# Epoch 257/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1014
# Epoch 258/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1015
# Epoch 259/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1018
# Epoch 260/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1017
# Epoch 261/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1016
# Epoch 262/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1014
# Epoch 263/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1014
# Epoch 264/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1021 - val_loss: 0.1014
# Epoch 265/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1014
# Epoch 266/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1013
# Epoch 267/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1014
# Epoch 268/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1013
# Epoch 269/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1020 - val_loss: 0.1012
# Epoch 270/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1014
# Epoch 271/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1013
# Epoch 272/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1014
# Epoch 273/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1013
# Epoch 274/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1013
# Epoch 275/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1014
# Epoch 276/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1012
# Epoch 277/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1011
# Epoch 278/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1019 - val_loss: 0.1012
# Epoch 279/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1012
# Epoch 280/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1012
# Epoch 281/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1014
# Epoch 282/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1011
# Epoch 283/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1010
# Epoch 284/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1011
# Epoch 285/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1018 - val_loss: 0.1011
# Epoch 286/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1014
# Epoch 287/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1012
# Epoch 288/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1011
# Epoch 289/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1014
# Epoch 290/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1010
# Epoch 291/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1012
# Epoch 292/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1011
# Epoch 293/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1012
# Epoch 294/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1012
# Epoch 295/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1011
# Epoch 296/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1012
# Epoch 297/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1010
# Epoch 298/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1012
# Epoch 299/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1011
# Epoch 300/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1017 - val_loss: 0.1010
# Epoch 301/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1012
# Epoch 302/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1010
# Epoch 303/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1012
# Epoch 304/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1012
# Epoch 305/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1009
# Epoch 306/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1012
# Epoch 307/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1011
# Epoch 308/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1009
# Epoch 309/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1011
# Epoch 310/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1009
# Epoch 311/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 312/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1010
# Epoch 313/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 314/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 315/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1008
# Epoch 316/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1009
# Epoch 317/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1009
# Epoch 318/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 319/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 320/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1012
# Epoch 321/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 322/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1009
# Epoch 323/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 324/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1011
# Epoch 325/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 326/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1015 - val_loss: 0.1009
# Epoch 327/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1010
# Epoch 328/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 329/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 330/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1010
# Epoch 331/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1010
# Epoch 332/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 333/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 334/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1007
# Epoch 335/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1010
# Epoch 336/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1009
# Epoch 337/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1009
# Epoch 338/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1010
# Epoch 339/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1009
# Epoch 340/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1009
# Epoch 341/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 342/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 343/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 344/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1009
# Epoch 345/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1008
# Epoch 346/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1009
# Epoch 347/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1011
# Epoch 348/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1008
# Epoch 349/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1009
# Epoch 350/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1010
# Epoch 351/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1011
# Epoch 352/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 353/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1008
# Epoch 354/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 355/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1010
# Epoch 356/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1014 - val_loss: 0.1007
# Epoch 357/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1009
# Epoch 358/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 359/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 360/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1009
# Epoch 361/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 362/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 363/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 364/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1008
# Epoch 365/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 366/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 367/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1008
# Epoch 368/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1008
# Epoch 369/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1008
# Epoch 370/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 371/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 372/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1008
# Epoch 373/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1013 - val_loss: 0.1007
# Epoch 374/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 375/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 376/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 377/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 378/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1009
# Epoch 379/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 380/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1006
# Epoch 381/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 382/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1008
# Epoch 383/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1008
# Epoch 384/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 385/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 386/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 387/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 388/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1007
# Epoch 389/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1008
# Epoch 390/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1006
# Epoch 391/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1006
# Epoch 392/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1012 - val_loss: 0.1006
# Epoch 393/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1008
# Epoch 394/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1007
# Epoch 395/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1007
# Epoch 396/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1007
# Epoch 397/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1007
# Epoch 398/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1007
# Epoch 399/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1006
# Epoch 400/400
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1011 - val_loss: 0.1007

# %%
n = 10

imgs = x_test[:n]
encoded_imgs = s_encoder.predict(imgs, batch_size=n)

decoded_imgs = s_decoder.predict(encoded_imgs, batch_size=n)

plot_digits(imgs, decoded_imgs)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fefb869a050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 42ms/step
